# %% [markdown]
# #Análise de Microdados do ENEM

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mediaEnemPorMunicipio = pd.read_csv('mediaEnemPorMunicipio.csv', sep=',')

# %%
mediaEnemPorMunicipio.head()
# Out:
#    Unnamed: 0  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0           0                  1100015   Alta Floresta D'Oeste
# 1           1                  1100023               Ariquemes
# 2           2                  1100031                  Cabixi
# 3           3                  1100049                  Cacoal
# 4           4                  1100056              Cerejeiras
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 0                11               RO  466.877454  493.412214  504.998473
# 1                11               RO  463.542845  489.960333  506.999802
# 2                11               RO  454.453125  474.152239  486.223881
# 3                11               RO  469.165657  494.664063  510.185132
# 4                11               RO  468.381164  488.456536  507.604902
#
#    NU_NOTA_MT  NU_NOTA_REDACAO
# 0  503.000000       555.776081
# 1  498.971037       524.149147
# 2  497.443750       492.835821
# 3  510.684635       538.657074
# 4  505.175685       552.222222

# %%
mediaEnemPorMunicipio = pd.read_csv('mediaEnemPorMunicipio.csv', sep=',', index_col=0)

# %%
mediaEnemPorMunicipio.head()
# Out:
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  1100015   Alta Floresta D'Oeste                11
# 1                  1100023               Ariquemes                11
# 2                  1100031                  Cabixi                11
# 3                  1100049                  Cacoal                11
# 4                  1100056              Cerejeiras                11
#
#   SG_UF_RESIDENCIA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0               RO  466.877454  493.412214  504.998473  503.000000
# 1               RO  463.542845  489.960333  506.999802  498.971037
# 2               RO  454.453125  474.152239  486.223881  497.443750
# 3               RO  469.165657  494.664063  510.185132  510.684635
# 4               RO  468.381164  488.456536  507.604902  505.175685
#
#    NU_NOTA_REDACAO
# 0       555.776081
# 1       524.149147
# 2       492.835821
# 3       538.657074
# 4       552.222222

# %%
#importando dados IDHM

# %%
atlasHumano = pd.read_csv('dados_brutos.csv', sep=';')

# %%
atlasHumano
# Out:
#        ANO  UF  Codmun6  Codmun7              Município   IDHM IDHM_E IDHM_L  \
# 0     2010  11   110001  1100015  ALTA FLORESTA D'OESTE  0,641  0,526  0,763
# 1     2010  11   110002  1100023              ARIQUEMES  0,702  0,600  0,806
# 2     2010  11   110003  1100031                 CABIXI  0,650  0,559  0,757
# 3     2010  11   110004  1100049                 CACOAL  0,718  0,620  0,821
# 4     2010  11   110005  1100056             CEREJEIRAS  0,692  0,602  0,799
# ...    ...  ..      ...      ...                    ...    ...    ...    ...
# 5560  2010  52   522200  5222005             VIANÓPOLIS  0,712  0,622  0,818
# 5561  2010  52   522205  5222054         VICENTINÓPOLIS  0,684  0,562  0,804
# 5562  2010  52   522220  5222203               VILA BOA  0,647  0,534  0,818
# 5563  2010  52   522230  5222302          VILA PROPÍCIO  0,634  0,505  0,802
# 5564  2010  53   530010  5300108               BRASÍLIA  0,824  0,742  0,873
#
#      IDHM_R
# 0     0,657
# 1     0,716
# 2     0,650
# 3     0,727
# 4     0,688
# ...     ...
# 5560  0,710
# 5561  0,707
# 5562  0,619
# 5563  0,629
# 5564  0,863
#
# [5565 rows x 9 columns]

# %%
colunasSelecionadas = ['ANO','UF', 'CODMUN6','CODMUN7','NOME_MUN','IDHM', 'IDHM_E','IDHM_L','IDHM_R']

# %%
atlasHumano = atlasHumano.filter(items= ['ANO','UF', 'Codmun6','Codmun7','Municipio','IDHM', 'IDHM_E','IDHM_L','IDHM_R'])

# %%
atlasHumano.head()
# Out:
#     ANO  UF  Codmun6  Codmun7   IDHM IDHM_E IDHM_L IDHM_R
# 0  2010  11   110001  1100015  0,641  0,526  0,763  0,657
# 1  2010  11   110002  1100023  0,702  0,600  0,806  0,716
# 2  2010  11   110003  1100031  0,650  0,559  0,757  0,650
# 3  2010  11   110004  1100049  0,718  0,620  0,821  0,727
# 4  2010  11   110005  1100056  0,692  0,602  0,799  0,688

# %%
pd.merge(mediaEnemPorMunicipio, atlasHumano, how = 'left',left_on = ['CO_MUNICIPIO_RESIDENCIA'], right_on = ['Codmun7'])
# Out:
#       CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                     1100015   Alta Floresta D'Oeste                11
# 1                     1100023               Ariquemes                11
# 2                     1100031                  Cabixi                11
# 3                     1100049                  Cacoal                11
# 4                     1100056              Cerejeiras                11
# ...                       ...                     ...               ...
# 5565                  5222005              Vianópolis                52
# 5566                  5222054          Vicentinópolis                52
# 5567                  5222203                Vila Boa                52
# 5568                  5222302           Vila Propício                52
# 5569                  5300108                Brasília                53
#
#      SG_UF_RESIDENCIA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0                  RO  466.877454  493.412214  504.998473  503.000000
# 1                  RO  463.542845  489.960333  506.999802  498.971037
# 2                  RO  454.453125  474.152239  486.223881  497.443750
# 3                  RO  469.165657  494.664063  510.185132  510.684635
# 4                  RO  468.381164  488.456536  507.604902  505.175685
# ...               ...         ...         ...         ...         ...
# 5565               GO  467.945495  492.496537  512.282684  528.815315
# 5566               GO  443.824194  469.941270  489.447619  504.204839
# 5567               GO  433.489130  446.955102  469.622449  474.306522
# 5568               GO  450.603636  464.472414  480.539655  474.847273
# 5569               DF  492.786286  523.134671  535.237884  536.788562
#
#       NU_NOTA_REDACAO     ANO    UF   Codmun6    Codmun7   IDHM IDHM_E IDHM_L  \
# 0          555.776081  2010.0  11.0  110001.0  1100015.0  0,641  0,526  0,763
# 1          524.149147  2010.0  11.0  110002.0  1100023.0  0,702  0,600  0,806
# 2          492.835821  2010.0  11.0  110003.0  1100031.0  0,650  0,559  0,757
# 3          538.657074  2010.0  11.0  110004.0  1100049.0  0,718  0,620  0,821
# 4          552.222222  2010.0  11.0  110005.0  1100056.0  0,692  0,602  0,799
# ...               ...     ...   ...       ...        ...    ...    ...    ...
# 5565       563.896104  2010.0  52.0  522200.0  5222005.0  0,712  0,622  0,818
# 5566       503.492063  2010.0  52.0  522205.0  5222054.0  0,684  0,562  0,804
# 5567       465.714286  2010.0  52.0  522220.0  5222203.0  0,647  0,534  0,818
# 5568       460.689655  2010.0  52.0  522230.0  5222302.0  0,634  0,505  0,802
# 5569       585.451783  2010.0  53.0  530010.0  5300108.0  0,824  0,742  0,873
#
#      IDHM_R
# 0     0,657
# 1     0,716
# 2     0,650
# 3     0,727
# 4     0,688
# ...     ...
# 5565  0,710
# 5566  0,707
# 5567  0,619
# 5568  0,629
# 5569  0,863
#
# [5570 rows x 17 columns]

# %%
mediaEnemIDHM = pd.merge(mediaEnemPorMunicipio, atlasHumano, how = 'left',left_on = ['CO_MUNICIPIO_RESIDENCIA'], right_on = ['Codmun7'])

# %%
mediaEnemIDHM
# Out:
#       CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                     1100015   Alta Floresta D'Oeste                11
# 1                     1100023               Ariquemes                11
# 2                     1100031                  Cabixi                11
# 3                     1100049                  Cacoal                11
# 4                     1100056              Cerejeiras                11
# ...                       ...                     ...               ...
# 5565                  5222005              Vianópolis                52
# 5566                  5222054          Vicentinópolis                52
# 5567                  5222203                Vila Boa                52
# 5568                  5222302           Vila Propício                52
# 5569                  5300108                Brasília                53
#
#      SG_UF_RESIDENCIA  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  \
# 0                  RO  466.877454  493.412214  504.998473  503.000000
# 1                  RO  463.542845  489.960333  506.999802  498.971037
# 2                  RO  454.453125  474.152239  486.223881  497.443750
# 3                  RO  469.165657  494.664063  510.185132  510.684635
# 4                  RO  468.381164  488.456536  507.604902  505.175685
# ...               ...         ...         ...         ...         ...
# 5565               GO  467.945495  492.496537  512.282684  528.815315
# 5566               GO  443.824194  469.941270  489.447619  504.204839
# 5567               GO  433.489130  446.955102  469.622449  474.306522
# 5568               GO  450.603636  464.472414  480.539655  474.847273
# 5569               DF  492.786286  523.134671  535.237884  536.788562
#
#       NU_NOTA_REDACAO     ANO    UF   Codmun6    Codmun7   IDHM IDHM_E IDHM_L  \
# 0          555.776081  2010.0  11.0  110001.0  1100015.0  0,641  0,526  0,763
# 1          524.149147  2010.0  11.0  110002.0  1100023.0  0,702  0,600  0,806
# 2          492.835821  2010.0  11.0  110003.0  1100031.0  0,650  0,559  0,757
# 3          538.657074  2010.0  11.0  110004.0  1100049.0  0,718  0,620  0,821
# 4          552.222222  2010.0  11.0  110005.0  1100056.0  0,692  0,602  0,799
# ...               ...     ...   ...       ...        ...    ...    ...    ...
# 5565       563.896104  2010.0  52.0  522200.0  5222005.0  0,712  0,622  0,818
# 5566       503.492063  2010.0  52.0  522205.0  5222054.0  0,684  0,562  0,804
# 5567       465.714286  2010.0  52.0  522220.0  5222203.0  0,647  0,534  0,818
# 5568       460.689655  2010.0  52.0  522230.0  5222302.0  0,634  0,505  0,802
# 5569       585.451783  2010.0  53.0  530010.0  5300108.0  0,824  0,742  0,873
#
#      IDHM_R
# 0     0,657
# 1     0,716
# 2     0,650
# 3     0,727
# 4     0,688
# ...     ...
# 5565  0,710
# 5566  0,707
# 5567  0,619
# 5568  0,629
# 5569  0,863
#
# [5570 rows x 17 columns]

# %%
mediaEnemIDHM.dtypes
# Out:
# CO_MUNICIPIO_RESIDENCIA      int64
# NO_MUNICIPIO_RESIDENCIA     object
# CO_UF_RESIDENCIA             int64
# SG_UF_RESIDENCIA            object
# NU_NOTA_CN                 float64
# NU_NOTA_CH                 float64
# NU_NOTA_LC                 float64
# NU_NOTA_MT                 float64
# NU_NOTA_REDACAO            float64
# ANO                        float64
# UF                         float64
# Codmun6                    float64
# Codmun7                    float64
# IDHM                        object
# IDHM_E                      object
# IDHM_L                      object
# IDHM_R                      object
# dtype: object

# %%
#é necessário substituir a virgula por ponto nos floats

# %%
mediaEnemIDHM['IDHM'] = mediaEnemIDHM['IDHM'].apply(lambda x: float(str(x).replace(',','.')))
mediaEnemIDHM['IDHM_R'] = mediaEnemIDHM['IDHM'].apply(lambda x: float(str(x).replace(',','.')))
mediaEnemIDHM['IDHM_E'] = mediaEnemIDHM['IDHM'].apply(lambda x: float(str(x).replace(',','.')))
mediaEnemIDHM['IDHM_L'] = mediaEnemIDHM['IDHM'].apply(lambda x: float(str(x).replace(',','.')))

# %%
numero = '0,651'
str(numero).replace(',','.')
# Out:
# '0.651'

# %%
mediaEnemIDHM.dtypes
# Out:
# CO_MUNICIPIO_RESIDENCIA      int64
# NO_MUNICIPIO_RESIDENCIA     object
# CO_UF_RESIDENCIA             int64
# SG_UF_RESIDENCIA            object
# NU_NOTA_CN                 float64
# NU_NOTA_CH                 float64
# NU_NOTA_LC                 float64
# NU_NOTA_MT                 float64
# NU_NOTA_REDACAO            float64
# ANO                        float64
# UF                         float64
# Codmun6                    float64
# Codmun7                    float64
# IDHM                       float64
# IDHM_E                     float64
# IDHM_L                     float64
# IDHM_R                     float64
# dtype: object

# %%
mediaEnemIDHM.plot.scatter('NU_NOTA_MT', 'IDHM',figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='NU_NOTA_MT', ylabel='IDHM'>

# %%
mediaEnemIDHM.plot.scatter('NU_NOTA_REDACAO', 'IDHM',figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='NU_NOTA_REDACAO', ylabel='IDHM'>
