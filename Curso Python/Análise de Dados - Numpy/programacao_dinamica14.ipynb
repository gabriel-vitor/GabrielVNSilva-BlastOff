# %%
import pandas as pd

# %%
microdadosEnem = pd.read_csv('MICRODADOS_ENEM_2019.csv', sep=';', encoding='ISO-8859-1')

# %%
microdadosEnem.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5095270 entries, 0 to 5095269
# Columns: 136 entries, NU_INSCRICAO to Q025
# dtypes: float64(25), int64(70), object(41)
# memory usage: 16.0 GB

# %%
#a recomendação é filtrar antes de importar, quando o dataset for muito grande. é
#possivel encontrar o nome das colunas através do dicionário do dataset

# %%
colunas = ['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA', 'NO_MUNICIPIO_RESIDENCIA','CO_UF_RESIDENCIA','SG_UF_RESIDENCIA', 'NU_IDADE']

# %%
microdadosEnemNovo = pd.read_csv('MICRODADOS_ENEM_2019.csv', sep=';', encoding='ISO-8859-1', usecols=colunas)

# %%
microdadosEnemNovo.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5095270 entries, 0 to 5095269
# Data columns (total 7 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   NU_INSCRICAO             int64
#  1   NU_ANO                   int64
#  2   CO_MUNICIPIO_RESIDENCIA  int64
#  3   NO_MUNICIPIO_RESIDENCIA  object
#  4   CO_UF_RESIDENCIA         int64
#  5   SG_UF_RESIDENCIA         object
#  6   NU_IDADE                 float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 855.9 MB

# %%
#diminuindo linhas (não recomendado)

# %%
microdadosEnemNovo2 = pd.read_csv('MICRODADOS_ENEM_2019.csv', sep=';', encoding='ISO-8859-1', nrows=10)

# %%
microdadosEnemNovo2
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  190001595656    2019                  3552205                Sorocaba
# 1  190001421546    2019                  2910800        Feira de Santana
# 2  190001133210    2019                  2304400               Fortaleza
# 3  190001199383    2019                  1721000                  Palmas
# 4  190001237802    2019                  3118601                Contagem
# 5  190001782198    2019                  5107602            Rondonópolis
# 6  190001421548    2019                  2924009            Paulo Afonso
# 7  190001595657    2019                  3550308               São Paulo
# 8  190001592264    2019                  3550308               São Paulo
# 9  190001592266    2019                  3550308               São Paulo
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                35               SP        36       M                1
# ...
